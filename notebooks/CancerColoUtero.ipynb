# %% [markdown]
# # **DADOS SUS**

# %% [markdown]
# ### **Exames citopatológicos realizados em mulheres na faixa etária de 25 a 64 anos**
#
#
# > Quantidade de exames citopatológicos (Papanicolau, Exame citopatológico cérvico-vaginal/microflora e Exame citopatológico cérvico-vaginal microflora-rastreamento) realizados em mulheres na faixa etária de 25 a 64 anos por município/UF de residência.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
bronze_df = pd.read_csv('ccmec25a64_main.csv')
print(bronze_df.columns.tolist())
bronze_df.head()
# Out:
# ['co_anomes', 'co_ibge', 'vl_indicador_calculado_mun', 'co_uf', 'no_municipio', 'sg_uf', 'no_uf', 'co_regiao_brasil', 'no_regiao_brasil', 'sg_regiao_brasil', 'co_regiao_saude', 'no_regiao_saude', 'no_macro', 'co_macro', 'vl_indicador_calculado_rs', 'vl_indicador_calculado_ms', 'vl_indicador_calculado_uf', 'vl_indicador_calculado_reg', 'vl_indicador_calculado_br', 'vl_indicador_calculado_al', 'dt_competencia', 'dt_atualizacao', 'ds_unidade_medida', 'sg_granularidade', 'ds_granularidade']
#    co_anomes  co_ibge  vl_indicador_calculado_mun  co_uf  \
# 0     202509   412440                         0.0     41
# 1     202509   412450                         0.0     41
# 2     202509   412460                         0.0     41
# 3     202509   412470                         0.0     41
# 4     202509   412480                         0.0     41
#
#                 no_municipio sg_uf   no_uf  co_regiao_brasil no_regiao_brasil  \
# 0  Santo Antônio Do Sudoeste    PR  Paraná                 4              Sul
# 1               Santo Inácio    PR  Paraná                 4              Sul
# 2         São Carlos Do Ivaí    PR  Paraná                 4              Sul
# 3      São Jerônimo Da Serra    PR  Paraná                 4              Sul
# 4                   São João    PR  Paraná                 4              Sul
#
#   sg_regiao_brasil  ...  vl_indicador_calculado_ms vl_indicador_calculado_uf  \
# 0                S  ...                      82364                    348381
# 1                S  ...                      50922                    348381
# 2                S  ...                      50922                    348381
# 3                S  ...                      49098                    348381
# 4                S  ...                      82364                    348381
#
#   vl_indicador_calculado_reg  vl_indicador_calculado_br  \
# 0                     890354                    5374386
# 1                     890354                    5374386
# 2                     890354                    5374386
# 3                     890354                    5374386
# 4                     890354                    5374386
#
#    vl_indicador_calculado_al       dt_competencia       dt_atualizacao  \
# 0                          0  2025-09-01 12:00:00  2026-02-04 23:45:18
# 1                          0  2025-09-01 12:00:00  2026-02-04 23:45:18
# 2                          0  2025-09-01 12:00:00  2026-02-04 23:45:18
# 3                          0  2025-09-01 12:00:00  2026-02-04 23:45:18
# 4                          0  2025-09-01 12:00:00  2026-02-04 23:45:18
#
#    ds_unidade_medida  sg_granularidade  ds_granularidade
# 0             Número                MN         Município
# 1             Número                MN         Município
# 2             Número                MN         Município
# 3             Número                MN         Município
# 4             Número                MN         Município
#
# [5 rows x 25 columns]

# %%
silver_df = bronze_df.drop(['co_anomes', 'co_ibge', 'co_uf', 'co_regiao_brasil', 'co_regiao_saude'], axis=1)

for column in silver_df.columns:
  print(f"{column}: {silver_df[column].isnull().unique()}")

silver_df.head()
# Out:
# vl_indicador_calculado_mun: [False]
# no_municipio: [False]
# sg_uf: [False]
# no_uf: [False]
# no_regiao_brasil: [False]
# sg_regiao_brasil: [False]
# no_regiao_saude: [False]
# no_macro: [False]
# co_macro: [False]
# vl_indicador_calculado_rs: [False]
# vl_indicador_calculado_ms: [False]
# vl_indicador_calculado_uf: [False]
# vl_indicador_calculado_reg: [False]
# vl_indicador_calculado_br: [False]
# vl_indicador_calculado_al: [False]
# dt_competencia: [False]
# dt_atualizacao: [False]
# ds_unidade_medida: [False]
# sg_granularidade: [False]
# ds_granularidade: [False]
#    vl_indicador_calculado_mun               no_municipio sg_uf   no_uf  \
# 0                         0.0  Santo Antônio Do Sudoeste    PR  Paraná
# 1                         0.0               Santo Inácio    PR  Paraná
# 2                         0.0         São Carlos Do Ivaí    PR  Paraná
# 3                         0.0      São Jerônimo Da Serra    PR  Paraná
# 4                         0.0                   São João    PR  Paraná
#
#   no_regiao_brasil sg_regiao_brasil           no_regiao_saude  \
# 0              Sul                S   8ª RS Francisco Beltrão
# 1              Sul                S            15ª RS Maringá
# 2              Sul                S          14ª RS Paranavaí
# 3              Sul                S  18ª RS Cornélio Procópio
# 4              Sul                S         7ª RS Pato Branco
#
#                   no_macro  co_macro  vl_indicador_calculado_rs  \
# 0       Macrorregião Oeste      4108                      36694
# 1  Macrorregional Noroeste      4106                      24225
# 2  Macrorregional Noroeste      4106                       7322
# 3     Macrorregional Norte      4105                          0
# 4       Macrorregião Oeste      4108                       5512
#
#    vl_indicador_calculado_ms  vl_indicador_calculado_uf  \
# 0                      82364                     348381
# 1                      50922                     348381
# 2                      50922                     348381
# 3                      49098                     348381
# 4                      82364                     348381
#
#    vl_indicador_calculado_reg  vl_indicador_calculado_br  \
# 0                      890354                    5374386
# 1                      890354                    5374386
# 2                      890354                    5374386
# 3                      890354                    5374386
# 4                      890354                    5374386
#
#    vl_indicador_calculado_al       dt_competencia       dt_atualizacao  \
# 0                          0  2025-09-01 12:00:00  2026-02-04 23:45:18
# 1                          0  2025-09-01 12:00:00  2026-02-04 23:45:18
# 2                          0  2025-09-01 12:00:00  2026-02-04 23:45:18
# 3                          0  2025-09-01 12:00:00  2026-02-04 23:45:18
# 4                          0  2025-09-01 12:00:00  2026-02-04 23:45:18
#
#   ds_unidade_medida sg_granularidade ds_granularidade
# 0            Número               MN        Município
# 1            Número               MN        Município
# 2            Número               MN        Município
# 3            Número               MN        Município
# 4            Número               MN        Município

# %% [markdown]
# ## **Organização dos Dados**
# Os dados estão estruturados como uma série temporal e geográfica (painel). Eles representam indicadores calculados em diferentes níveis (município, região de saúde, estado, macrorregião e país).
#
# ## **Variáveis Independentes**
#
# São as variáveis que definem o cenário ou a localização do dado. Elas não mudam em função do indicador, mas servem para agrupá-lo:
#
# **Temporais:** `co_anomes, dt_competencia` (Mês e ano da competência).
#
# **Geográficas/Categorias:** `no_municipio` (nome), `sg_uf` (sigla do estado), `no_regiao_brasil` (região), `no_regiao_saude, no_macro`. Essas variáveis são fundamentais para filtros e agrupamentos.
#
# ## **Variáveis Dependentes**
#
# São os valores calculados que queremos analisar ou prever:
#
# `vl_indicador_calculado_mun`: O valor principal para o município.
#
# `vl_indicador_calculado_rs`,`vl_indicador_calculado_uf`, `vl_indicador_calculado_br`: O valor consolidado em níveis maiores (Região de Saúde, Estado e Brasil, respectivamente).
